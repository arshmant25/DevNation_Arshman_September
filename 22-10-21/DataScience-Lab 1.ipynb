# %%
import pandas as pd

# %%
df=pd.read_csv('C:\DevN\DataLibs_21sept\\Copy_of_olympics.csv')

# %%
df.head()
# Out:
#                 Unnamed: 0  № Summer  01 !  02 !  03 !  Total  № Winter  \
# 0        Afghanistan (AFG)        13     0     0     2      2         0
# 1            Algeria (ALG)        12     5     2     8     15         3
# 2          Argentina (ARG)        23    18    24    28     70        18
# 3            Armenia (ARM)         5     1     2     9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3     4     5     12         0
#
#    01 !.1  02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  03 !.2  \
# 0       0       0       0        0       13       0       0       2
# 1       0       0       0        0       15       5       2       8
# 2       0       0       0        0       41      18      24      28
# 3       0       0       0        0       11       1       2       9
# 4       0       0       0        0        2       3       4       5
#
#    Combined total
# 0               2
# 1              15
# 2              70
# 3              12
# 4              12

# %%
df.rename(columns={'Unnamed: 0': 'Countries', '№ Summer': 'Summer_games','01 !':'Summer_gold','02 !':'Summer_silver',
                   '03 !':'Summer_bronze','Total':'Total_summer','№ Winter':'Winter_games','01 !.1':'Winter_gold',
                  '02 !.1':'Winter_silver','03 !.1':'Winter_bronze','Total.1':'Total_winter','№ Games':'Total_games',
                  '01 !.2':'Total_gold','02 !.2':'Total_silver','03 !.2':'Total_bronze','Combined total':'Total_medals'}, inplace=True)

# %%
df.tail()
# Out:
#                                         Countries  Summer_games  Summer_gold  \
# 142  Independent Olympic Participants (IOP) [IOP]             1            0
# 143                            Zambia (ZAM) [ZAM]            12            0
# 144                          Zimbabwe (ZIM) [ZIM]            12            3
# 145                        Mixed team (ZZX) [ZZX]             3            8
# 146                                        Totals            27         4809
#
#      Summer_silver  Summer_bronze  Total_summer  Winter_games  Winter_gold  \
# 142              1              2             3             0            0
# 143              1              1             2             0            0
# 144              4              1             8             1            0
# 145              5              4            17             0            0
# 146           4775           5130         14714            22          959
#
#      Winter_silver  Winter_bronze  Total_winter  Total_games  Total_gold  \
# 142              0              0             0            1           0
# 143              0              0             0           12           0
# 144              0              0             0           13           3
# 145              0              0             0            3           8
# 146            958            948          2865           49        5768
#
#      Total_silver  Total_bronze  Total_medals
# 142             1             2             3
# 143             1             1             2
# 144             4             1             8
# 145             5             4            17
# 146          5733          6078         17579

# %%
#Q1
df['Countries'].iloc[0]
# Out:
# 'Afghanistan\xa0(AFG)'

# %%
df=df.drop(146)

# %%
df.tail()
# Out:
#                                         Countries  Summer_games  Summer_gold  \
# 141                        Yugoslavia (YUG) [YUG]            16           26
# 142  Independent Olympic Participants (IOP) [IOP]             1            0
# 143                            Zambia (ZAM) [ZAM]            12            0
# 144                          Zimbabwe (ZIM) [ZIM]            12            3
# 145                        Mixed team (ZZX) [ZZX]             3            8
#
#      Summer_silver  Summer_bronze  Total_summer  Winter_games  Winter_gold  \
# 141             29             28            83            14            0
# 142              1              2             3             0            0
# 143              1              1             2             0            0
# 144              4              1             8             1            0
# 145              5              4            17             0            0
#
#      Winter_silver  Winter_bronze  Total_winter  Total_games  Total_gold  \
# 141              3              1             4           30          26
# 142              0              0             0            1           0
# 143              0              0             0           12           0
# 144              0              0             0           13           3
# 145              0              0             0            3           8
#
#      Total_silver  Total_bronze  Total_medals
# 141            32            29            87
# 142             1             2             3
# 143             1             1             2
# 144             4             1             8
# 145             5             4            17

# %%
'''
#I think the easiest way to return a row with the maximum value is by getting its index. argmax() can be used to return the index of 
#the row with the largest value.
'''
index = df.Summer_gold.argmax()

# %%
index
# Out:
# 135

# %%
#Q2 
df.iloc[df.Summer_gold.argmax(), 0] #0 defines as 1d feature
# Out:
# 'United States\xa0(USA) [P] [Q] [R] [Z]'

# %%
df.groupby('Countries')['Summer_gold'].sum().nlargest(1)
# Out:
# Countries
# United States (USA) [P] [Q] [R] [Z]    976
# Name: Summer_gold, dtype: int64

# %%
df[df['Summer_gold']==df['Summer_gold'].max()]
# Out:
#                                Countries  Summer_games  Summer_gold  \
# 135  United States (USA) [P] [Q] [R] [Z]            26          976
#
#      Summer_silver  Summer_bronze  Total_summer  Winter_games  Winter_gold  \
# 135            757            666          2399            22           96
#
#      Winter_silver  Winter_bronze  Total_winter  Total_games  Total_gold  \
# 135            102             84           282           48        1072
#
#      Total_silver  Total_bronze  Total_medals
# 135           859           750          2681

# %%
#Q3
(df['Summer_gold'] - df['Winter_gold']).idxmax()
# Out:
# 135

# %%
df.iloc[(df['Summer_gold'] - df['Winter_gold']).abs().idxmax(), 0]
# Out:
# 'United States\xa0(USA) [P] [Q] [R] [Z]'

# %%
pd.Series(df['Summer_gold']-df['Winter_gold']).argmax() #arg returns position, idx returns label
# Out:
# 135

# %%
#Q4 returning index of the country with max relative distance
((df['Summer_gold'] - df['Winter_gold'])/df['Total_gold']).idxmax()
# Out:
# 1

# %%
df.iloc[((df['Summer_gold'] - df['Winter_gold'])/df['Total_gold']).abs().idxmax(), 0]
# Out:
# 'Algeria\xa0(ALG)'

# %%
df.head(2)
# Out:
#            Countries  Summer_games  Summer_gold  Summer_silver  Summer_bronze  \
# 0  Afghanistan (AFG)            13            0              0              2
# 1      Algeria (ALG)            12            5              2              8
#
#    Total_summer  Winter_games  Winter_gold  Winter_silver  Winter_bronze  \
# 0             2             0            0              0              0
# 1            15             3            0              0              0
#
#    Total_winter  Total_games  Total_gold  Total_silver  Total_bronze  \
# 0             0           13           0             0             2
# 1             0           15           5             2             8
#
#    Total_medals
# 0             2
# 1            15

# %%
#Q5
def point():
    points= (df.Winter_gold*3)+(df.Winter_silver*2)+df.Winter_bronze
    
    return pd.Series(points, index=df.index)

# %%
a=point()

# %%
a
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 141    7
# 142    0
# 143    0
# 144    0
# 145    0
# Length: 146, dtype: int64

# %%
a[141]
# Out:
# 7

# %%
a.iloc(0)

# %% [markdown]
# ## Part 2

# %%
df1=pd.read_csv('C:\DevN\DataLibs_21sept\\Copy of census.csv')

# %%
df1.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0     1.030015     0.826644     1.383282     1.724718     0.712594
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
#
# [5 rows x 100 columns]

# %%
#Q1
df1.groupby('STNAME')['COUNTY'].nunique()
# Out:
# STNAME
# Alabama                  68
# Alaska                   30
# Arizona                  16
# Arkansas                 76
# California               59
# Colorado                 65
# Connecticut               9
# Delaware                  4
# District of Columbia      2
# Florida                  68
# Georgia                 160
# Hawaii                    6
# Idaho                    45
# Illinois                103
# Indiana                  93
# Iowa                    100
# Kansas                  106
# Kentucky                121
# Louisiana                65
# Maine                    17
# Maryland                 25
# Massachusetts            15
# Michigan                 84
# Minnesota                88
# Mississippi              83
# Missouri                116
# Montana                  57
# Nebraska                 94
# Nevada                   18
# New Hampshire            11
# New Jersey               22
# New Mexico               34
# New York                 63
# North Carolina          101
# North Dakota             54
# Ohio                     89
# Oklahoma                 78
# Oregon                   37
# Pennsylvania             68
# Rhode Island              6
# South Carolina           47
# South Dakota             67
# Tennessee                96
# Texas                   255
# Utah                     30
# Vermont                  15
# Virginia                134
# Washington               40
# West Virginia            56
# Wisconsin                73
# Wyoming                  24
# Name: COUNTY, dtype: int64

# %%
df1.groupby('STNAME')['COUNTY'].count().nlargest(1)
# Out:
# STNAME
# Texas    255
# Name: COUNTY, dtype: int64

# %%
#Q2
df1.groupby('STNAME')['CENSUS2010POP'].sum().nlargest(3)
# Out:
# STNAME
# California    74507912
# Texas         50291122
# New York      38756204
# Name: CENSUS2010POP, dtype: int64

# %%
df1.CENSUS2010POP.argmax()
# Out:
# 190

# %%
#Q7
df1["Diff"] = (df1[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014',
             'POPESTIMATE2015']].max(axis=1)-df1[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014',
             'POPESTIMATE2015']].min(axis=1))

# %%
df1
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# 0           4779736            4780127          4785161  ...
# 1             54571              54571            54660  ...
# 2            182265             182265           183193  ...
# 3             27457              27457            27341  ...
# 4             22915              22919            22861  ...
# ...             ...                ...              ...  ...
# 3188          43806              43806            43593  ...
# 3189          21294              21294            21297  ...
# 3190          21118              21118            21102  ...
# 3191           8533               8533             8545  ...
# 3192           7208               7208             7181  ...
#
#       RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0            -0.193196          0.381066          0.582002         -0.467369
# 1            -2.915927         -3.012349          2.265971         -2.530799
# 2            17.647293         21.845705         19.243287         17.197872
# 3            -2.500690         -7.056824         -3.904217        -10.543299
# 4            -5.068871         -6.201001         -0.177537          0.177258
# ...                ...               ...               ...               ...
# 3188         16.243199         -5.339774        -14.252889        -14.248864
# 3189          0.972695         19.525929         14.143021         -0.564849
# 3190         -4.916350         -6.902954        -14.215862        -12.127022
# 3191         -0.827815         -2.013502        -17.781491          1.682288
# 3192         -8.040059         12.372583          1.533635          6.935294
#
#       RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015   Diff
# 0        1.030015     0.826644     1.383282     1.724718     0.712594  73818
# 1        7.606016    -2.626146    -2.722002     2.592270    -2.187333    687
# 2       15.844176    18.559627    22.727626    20.317142    18.293499  20516
# 3       -4.874741    -2.758113    -7.167664    -3.978583   -10.543299    852
# 4       -5.088389    -4.363636    -5.403729     0.754533     1.107861    349
# ...           ...          ...          ...          ...          ...    ...
# 3188     1.255221    16.243199    -5.295460   -14.075283   -14.070195   1569
# 3189     0.654527     2.408578    21.160658    16.308671     1.520747   1828
# 3190   -18.136812    -5.536861    -7.521840   -14.740608   -12.606351    280
# 3191   -11.990126    -1.182592    -2.250385   -18.020168     1.441961    229
# 3192   -12.032179    -8.040059    12.372583     1.533635     6.935294    169
#
# [3193 rows x 101 columns]

# %%
#df1.groupby('CTYNAME')['Diff'].transform(max)
# Out:
# 0       73818
# 1         687
# 2       20516
# 3         852
# 4        2402
#         ...
# 3188     1569
# 3189     1828
# 3190      280
# 3191      229
# 3192      169
# Name: Diff, Length: 3193, dtype: int64

# %%
df1.groupby(by='CTYNAME')['Diff'].idxmax().nlargest(5)
# Out:
# CTYNAME
# Weston County        3192
# Washakie County      3191
# Uinta County         3190
# Teton County         3189
# Sweetwater County    3188
# Name: Diff, dtype: int64

# %%
df1.iloc[df1.groupby(by='CTYNAME')['Diff'].idxmax()]
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY          STNAME  \
# 2357      50       3         5     45       1  South Carolina
# 1132      50       3         7     22       1       Louisiana
# 2867      50       3         5     51       1        Virginia
# 564       50       4         8     16       1           Idaho
# 2168      50       3         7     40       1        Oklahoma
# ...      ...     ...       ...    ...     ...             ...
# 97        50       4         9      2     290          Alaska
# 113       50       4         8      4      27         Arizona
# 2819      50       3         7     48     505           Texas
# 2820      50       3         7     48     507           Texas
# 2469      50       2         4     46     137    South Dakota
#
#                         CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# 2357           Abbeville County          25417              25416
# 1132              Acadia Parish          61773              61773
# 2867            Accomack County          33164              33164
# 564                  Ada County         392365             392365
# 2168               Adair County          22683              22683
# ...                         ...            ...                ...
# 97    Yukon-Koyukuk Census Area           5588               5588
# 113                 Yuma County         195751             195750
# 2819              Zapata County          14018              14018
# 2820              Zavala County          11677              11677
# 2469             Ziebach County           2801               2801
#
#       POPESTIMATE2010  ...  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# 2357            25338  ...         -4.027434         -3.838158
# 1132            61856  ...         -3.074110          1.145392
# 2867            33165  ...         -2.312278         -9.650326
# 564            393464  ...         11.372713         11.122419
# 2168            22731  ...        -13.531316         -6.472492
# ...               ...  ...               ...               ...
# 97               5588  ...         -4.885709        -17.029494
# 113            197069  ...        -13.713479        -13.412500
# 2819            14075  ...        -10.822207         -5.659784
# 2820            11711  ...         -0.168315          4.320552
# 2469             2825  ...         -0.700525        -17.534631
#
#       RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  \
# 2357         -1.643320         -0.481367    -6.264497    -3.349549
# 1132          1.075243         -4.493304    -4.190294    -2.685802
# 2867         -0.090905         -1.606767     3.280563    -0.030030
# 564          15.596132          8.914614    11.752535    13.249236
# 2168         -5.181230         -7.880970   -10.517478   -13.397343
# ...                ...               ...          ...          ...
# 97          -22.095510         -6.669070     7.597844    -4.536730
# 113          -6.000158         -7.332781    17.978619   -10.424614
# 2819        -16.442556         -8.499669    -7.636556   -10.892481
# 2820         -9.548111         -6.310182    -2.974546     1.094046
# 2469        -16.979130        -13.153217    -5.650715     0.000000
#
#       RNETMIG2013  RNETMIG2014  RNETMIG2015   Diff
# 2357    -3.078522    -0.761538     0.401139    412
# 1132     1.580964     1.588792    -3.981611    814
# 2867    -7.659947     2.212021     0.848858    341
# 564     13.051275    17.773330    11.081716  40747
# 2168    -6.337648    -5.046068    -7.745091    727
# ...           ...          ...          ...    ...
# 97     -16.678371   -21.739130    -6.308580    198
# 113    -10.456114    -2.889147    -3.918991   7206
# 2819    -5.450162   -16.094196    -8.081653    299
# 2820     5.816127    -7.901885    -4.671174    524
# 2469   -16.833246   -16.271666   -12.442232     69
#
# [1927 rows x 101 columns]

# %%
#Q8
b=df1.query('REGION < 3 & POPESTIMATE2015 > POPESTIMATE2014 & CTYNAME == "Washington County" ').head()

# %%
b[['STNAME','CTYNAME']]
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County

# %%
import pandas as pd

# %%
df=pd.read_excel('C:\DevN\DSlab2\Energy+Indicators.xls')

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0         NaN        NaN                   Environmental Indicators: Energy
# 1         NaN        NaN                                                NaN
# 2         NaN        NaN  Energy Supply and Renewable Electricity Produc...
# 3         NaN        NaN                                                NaN
# 4         NaN        NaN                                                NaN
#
#   Unnamed: 3 Unnamed: 4                  Unnamed: 5
# 0        NaN        NaN                         NaN
# 1        NaN        NaN                         NaN
# 2        NaN        NaN                         NaN
# 3        NaN        NaN                         NaN
# 4        NaN        NaN  Last update: December 2015

# %%
df = pd.read_excel('C:\DevN\DSlab2\Energy+Indicators.xls', header=16, skipfooter=38)

# %%
df.head()
# Out:
#    Unnamed: 0      Unnamed: 1      Unnamed: 2 Energy Supply  \
# 0         NaN             NaN             NaN    Petajoules
# 1         NaN     Afghanistan     Afghanistan           321
# 2         NaN         Albania         Albania           102
# 3         NaN         Algeria         Algeria          1959
# 4         NaN  American Samoa  American Samoa           ...
#
#   Energy Supply per capita Renewable Electricity Production
# 0               Gigajoules                                %
# 1                       10                          78.6693
# 2                       35                              100
# 3                       51                          0.55101
# 4                      ...                         0.641026

# %%
df.tail()
# Out:
#      Unnamed: 0                 Unnamed: 1                 Unnamed: 2  \
# 223         NaN                   Viet Nam                   Viet Nam
# 224         NaN  Wallis and Futuna Islands  Wallis and Futuna Islands
# 225         NaN                      Yemen                      Yemen
# 226         NaN                     Zambia                     Zambia
# 227         NaN                   Zimbabwe                   Zimbabwe
#
#     Energy Supply Energy Supply per capita Renewable Electricity Production
# 223          2554                       28                          45.3215
# 224             0                       26                                0
# 225           344                       13                                0
# 226           400                       26                          99.7147
# 227           480                       32                          52.5361

# %%
df=df.drop(0)

# %%
df.head()
# Out:
#    Unnamed: 0      Unnamed: 1      Unnamed: 2 Energy Supply  \
# 1         NaN     Afghanistan     Afghanistan           321
# 2         NaN         Albania         Albania           102
# 3         NaN         Algeria         Algeria          1959
# 4         NaN  American Samoa  American Samoa           ...
# 5         NaN         Andorra         Andorra             9
#
#   Energy Supply per capita Renewable Electricity Production
# 1                       10                          78.6693
# 2                       35                              100
# 3                       51                          0.55101
# 4                      ...                         0.641026
# 5                      121                          88.6957

# %%
df.drop(['Unnamed: 0','Unnamed: 1'], axis = 1)
# Out:
#                     Unnamed: 2 Energy Supply Energy Supply per capita  \
# 1                  Afghanistan           321                       10
# 2                      Albania           102                       35
# 3                      Algeria          1959                       51
# 4               American Samoa           ...                      ...
# 5                      Andorra             9                      121
# ..                         ...           ...                      ...
# 223                   Viet Nam          2554                       28
# 224  Wallis and Futuna Islands             0                       26
# 225                      Yemen           344                       13
# 226                     Zambia           400                       26
# 227                   Zimbabwe           480                       32
#
#     Renewable Electricity Production
# 1                            78.6693
# 2                                100
# ...

# %%
df.rename(columns={'Unnamed: 2': 'Country', 'Renewable Electricity Production': '% Renewable'}, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0      Unnamed: 1         Country Energy Supply  \
# 1         NaN     Afghanistan     Afghanistan           321
# 2         NaN         Albania         Albania           102
# 3         NaN         Algeria         Algeria          1959
# 4         NaN  American Samoa  American Samoa           ...
# 5         NaN         Andorra         Andorra             9
#
#   Energy Supply per capita % Renewable
# 1                       10     78.6693
# 2                       35         100
# 3                       51     0.55101
# 4                      ...    0.641026
# 5                      121     88.6957

# %%
df=df.drop(['Unnamed: 0','Unnamed: 1'], axis = 1)

# %%
df.head()
# Out:
#           Country Energy Supply Energy Supply per capita % Renewable
# 1     Afghanistan           321                       10     78.6693
# 2         Albania           102                       35         100
# 3         Algeria          1959                       51     0.55101
# 4  American Samoa           ...                      ...    0.641026
# 5         Andorra             9                      121     88.6957

# %%
df.tail()
# Out:
#                        Country Energy Supply Energy Supply per capita  \
# 223                   Viet Nam          2554                       28
# 224  Wallis and Futuna Islands             0                       26
# 225                      Yemen           344                       13
# 226                     Zambia           400                       26
# 227                   Zimbabwe           480                       32
#
#     % Renewable
# 223     45.3215
# 224           0
# 225           0
# 226     99.7147
# 227     52.5361

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 1 to 227
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   227 non-null    object
#  1   Energy Supply             227 non-null    object
#  2   Energy Supply per capita  227 non-null    object
#  3   % Renewable               227 non-null    object
# dtypes: object(4)
# memory usage: 8.9+ KB

# %%
import numpy as np

# %%
df=df.replace('...', np.NaN)

# %%
df.head()
# Out:
#           Country  Energy Supply  Energy Supply per capita  % Renewable
# 1     Afghanistan          321.0                      10.0    78.669280
# 2         Albania          102.0                      35.0   100.000000
# 3         Algeria         1959.0                      51.0     0.551010
# 4  American Samoa            NaN                       NaN     0.641026
# 5         Andorra            9.0                     121.0    88.695650

# %%
df['Energy Supply']= 1000000 * df['Energy Supply']

# %%
df.head()
# Out:
#           Country  Energy Supply  Energy Supply per capita  % Renewable
# 1     Afghanistan   3.210000e+08                      10.0    78.669280
# 2         Albania   1.020000e+08                      35.0   100.000000
# 3         Algeria   1.959000e+09                      51.0     0.551010
# 4  American Samoa            NaN                       NaN     0.641026
# 5         Andorra   9.000000e+06                     121.0    88.695650

# %%
#removing numbers from string
df['Country'] = df['Country'].str.replace('\d+', '')

# %%
#removing parantheses and inside text of parantheses
df['Country'] = df['Country'].str.replace(r"\(.*\)","")

# %%
df['Country'].tolist()
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia ',
#  'Bonaire, Sint Eustatius and Saba',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'China, Hong Kong Special Administrative Region',
#  'China, Macao Special Administrative Region',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  "Côte d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czech Republic',
# ...

# %%
df["Country"].replace({"Republic of Korea": "South Korea", "United States of America": "United States",
                      "United Kingdom of Great Britain and Northern Ireland":"United Kingdom","China, Hong Kong Special Administrative Region": "Hong Kong",
                      'Iran ':'Iran'}, inplace=True)

# %%
df['Country'].tolist()
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia ',
#  'Bonaire, Sint Eustatius and Saba',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Hong Kong',
#  'China, Macao Special Administrative Region',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  "Côte d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czech Republic',
# ...

# %%
#reading world bank file and skipping headers
df1=pd.read_csv('C:\DevN\DSlab2\world_bank.csv',header=4)

# %%
df1.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1      Andorra          AND  GDP at market prices (constant 2010 US$)
# 2  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3       Angola          AGO  GDP at market prices (constant 2010 US$)
# 4      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2006  \
# 0  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 1  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.018196e+09
# 2  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.030523e+10
# 3  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.581103e+10
# 4  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.771760e+09
#
#            2007          2008          2009          2010          2011  \
# ...

# %%
df1['Country Name'].tolist()
# Out:
# ['Aruba',
#  'Andorra',
#  'Afghanistan',
#  'Angola',
#  'Albania',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Channel Islands',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Curacao',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
# ...

# %%
df1["Country Name"].replace({"Korea, Rep.": "South Korea", "Iran, Islamic Rep.": "Iran","Hong Kong SAR, China": "Hong Kong"}, inplace=True)

# %%
df1['Country Name'].tolist()
# Out:
# ['Aruba',
#  'Andorra',
#  'Afghanistan',
#  'Angola',
#  'Albania',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Channel Islands',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Curacao',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
# ...

# %%
df1.rename(columns={'Country Name': 'Country'}, inplace=True)

# %%
df1.head()
# Out:
#        Country Country Code                            Indicator Name  \
# 0        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1      Andorra          AND  GDP at market prices (constant 2010 US$)
# 2  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3       Angola          AGO  GDP at market prices (constant 2010 US$)
# 4      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2006  \
# 0  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 1  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.018196e+09
# 2  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.030523e+10
# 3  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.581103e+10
# 4  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.771760e+09
#
#            2007          2008          2009          2010          2011  \
# ...

# %%
df2=pd.read_excel('C:\DevN\DSlab2\scimagojr-3.xlsx')

# %%
df2.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %%
display('df', 'df1','df2',
        "pd.merge(df, df1,df2, left_index=True)")
# Out:
# 'df'
# 'df1'
# 'df2'
# 'pd.merge(df, df1,df2, left_index=True)'

# %%
 df3 = pd.merge(pd.merge(df, df1, on='Country'), df2, on='Country')

# %%
temp_df=pd.merge(df,df1,on='Country')

# %%
pd.merge(temp_df,df2,on='Country')
# Out:
#             Country  Energy Supply  Energy Supply per capita  % Renewable  \
# 0       Afghanistan   3.210000e+08                      10.0    78.669280
# 1           Albania   1.020000e+08                      35.0   100.000000
# 2           Algeria   1.959000e+09                      51.0     0.551010
# 3    American Samoa            NaN                       NaN     0.641026
# 4           Andorra   9.000000e+06                     121.0    88.695650
# ..              ...            ...                       ...          ...
# 156   United States   9.083800e+10                     286.0    11.570980
# 157         Uruguay   1.960000e+08                      58.0    71.605040
# 158      Uzbekistan   1.798000e+09                      62.0    21.328410
# 159          Zambia   4.000000e+08                      26.0    99.714670
# 160        Zimbabwe   4.800000e+08                      32.0    52.536120
#
#     Country Code                            Indicator Name  Indicator Code  \
# ...

# %%
df3.head()
# Out:
#           Country  Energy Supply  Energy Supply per capita  % Renewable  \
# 0     Afghanistan   3.210000e+08                      10.0    78.669280
# 1         Albania   1.020000e+08                      35.0   100.000000
# 2         Algeria   1.959000e+09                      51.0     0.551010
# 3  American Samoa            NaN                       NaN     0.641026
# 4         Andorra   9.000000e+06                     121.0    88.695650
#
#   Country Code                            Indicator Name  Indicator Code  \
# 0          AFG  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 1          ALB  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 2          DZA  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 3          ASM  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 4          AND  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
#
#            1960          1961          1962  ...          2013          2014  \
# ...

# %%
df4=df3.set_index('Country')

# %%
df4.head()
# Out:
#                 Energy Supply  Energy Supply per capita  % Renewable  \
# Country
# Afghanistan      3.210000e+08                      10.0    78.669280
# Albania          1.020000e+08                      35.0   100.000000
# Algeria          1.959000e+09                      51.0     0.551010
# American Samoa            NaN                       NaN     0.641026
# Andorra          9.000000e+06                     121.0    88.695650
#
#                Country Code                            Indicator Name  \
# Country
# Afghanistan             AFG  GDP at market prices (constant 2010 US$)
# Albania                 ALB  GDP at market prices (constant 2010 US$)
# Algeria                 DZA  GDP at market prices (constant 2010 US$)
# American Samoa          ASM  GDP at market prices (constant 2010 US$)
# Andorra                 AND  GDP at market prices (constant 2010 US$)
#
#                 Indicator Code          1960          1961          1962  \
# Country
# ...

# %%
df4=df4.drop(df4.loc[:, 'Country Code':'2005'].columns, axis = 1)

# %%
#df4 = df4.sort(['Rank'], ascending=[True])

# %%
df4=df4.sort_values('Rank')

# %%
df4
# Out:
#                     Energy Supply  Energy Supply per capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0     19.75491
# United States        9.083800e+10                     286.0     11.57098
# Japan                1.898400e+10                     149.0     10.23282
# United Kingdom       7.920000e+09                     124.0     10.60047
# Russian Federation   3.070900e+10                     214.0     17.28868
# ...                           ...                       ...          ...
# Maldives             1.500000e+07                      43.0      0.00000
# Belize               1.300000e+07                      39.0     64.69003
# Palau                3.000000e+06                     152.0     18.75000
# Guyana               3.400000e+07                      45.0      0.00000
# Mauritania           5.100000e+07                      13.0      0.00000
#
#                             2006          2007          2008          2009  \
# ...

# %%
df5 = df4.loc[(df4["Rank"] < 16)]

# %%
df5
# Out:
#                     Energy Supply  Energy Supply per capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# United States        9.083800e+10                     286.0    11.570980
# Japan                1.898400e+10                     149.0    10.232820
# United Kingdom       7.920000e+09                     124.0    10.600470
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# ...

# %%
df5=df5.sort_values('Rank')

# %%
df5
# Out:
#                     Energy Supply  Energy Supply per capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# United States        9.083800e+10                     286.0    11.570980
# Japan                1.898400e+10                     149.0    10.232820
# United Kingdom       7.920000e+09                     124.0    10.600470
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# ...

# %%
#Q2 Length before readucing and after reducing
len(df4)-len(df5)
# Out:
# 146

# %%
df5.shape
# Out:
# (15, 20)

# %%
#df5['avg GDP'] = df.mean(axis=1)

# %%
#Q3
df6=df5[["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"]].apply(np.mean,axis = 1).sort_values(ascending = False)

# %%
df6
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %%
#Q5
df5['Energy Supply per capita'].mean()
# Out:
# 157.6

# %%
#Q6
df5.groupby('Country')['% Renewable'].sum().nlargest(1)
# Out:
# Country
# Brazil    69.64803
# Name: % Renewable, dtype: float64

# %%
#Q7
df5['Ratio Citations']=df5['Self-citations']/df5['Citations']

# %%
df5
# Out:
#                     Energy Supply  Energy Supply per capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# United States        9.083800e+10                     286.0    11.570980
# Japan                1.898400e+10                     149.0    10.232820
# United Kingdom       7.920000e+09                     124.0    10.600470
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# ...

# %%
#Q7
df5.groupby('Country')['Ratio Citations'].sum().nlargest(1)
# Out:
# Country
# China    0.689313
# Name: Ratio Citations, dtype: float64

# %%
#Q8
df5['Polpulation']=df5['Energy Supply']/df5['Energy Supply per capita']

# %%
df5.head()
# Out:
#                     Energy Supply  Energy Supply per capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0     19.75491
# United States        9.083800e+10                     286.0     11.57098
# Japan                1.898400e+10                     149.0     10.23282
# United Kingdom       7.920000e+09                     124.0     10.60047
# Russian Federation   3.070900e+10                     214.0     17.28868
#
#                             2006          2007          2008          2009  \
# Country
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# United States       1.479230e+13  1.505540e+13  1.501149e+13  1.459484e+13
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# United Kingdom      2.419631e+12  2.482203e+12  2.470614e+12  2.367048e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
#
# ...

# %%
df5.groupby('Country')['Polpulation'].sum().nlargest(3)
# Out:
# Country
# China            1.367645e+09
# India            1.276731e+09
# United States    3.176154e+08
# Name: Polpulation, dtype: float64

# %%
df6=df5

# %%
df6=df6.sort_values('Polpulation', ascending=[False])

# %%
df6
# Out:
#                     Energy Supply  Energy Supply per capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# India                3.319500e+10                      26.0    14.969080
# United States        9.083800e+10                     286.0    11.570980
# Brazil               1.214900e+10                      59.0    69.648030
# Russian Federation   3.070900e+10                     214.0    17.288680
# Japan                1.898400e+10                     149.0    10.232820
# Germany              1.326100e+10                     165.0    17.901530
# Iran                 9.172000e+09                     119.0     5.707721
# United Kingdom       7.920000e+09                     124.0    10.600470
# France               1.059700e+10                     166.0    17.020280
# Italy                6.530000e+09                     109.0    33.667230
# South Korea          1.100700e+10                     221.0     2.279353
# ...

# %%
df6.iloc[2].name
# Out:
# 'United States'

# %%
#Q9
df6['CitablesPerPerson']=df6['Citable documents']/df6['Polpulation']

# %%
df6['CitablesPerPerson'].corr(df6['Energy Supply per capita'])
# Out:
# 0.7940010435442942

# %%
#Q10
df6['% Renewable'].median()
# Out:
# 17.02028

# %%
df6.rename(columns={'% Renewable': 'PercentageRenewable'}, inplace=True)

# %%
df6['RenewableAsPerMedian']=np.where(((df6.PercentageRenewable >= 17.02028)),'1','0')

# %%
df6
# Out:
#                     Energy Supply  Energy Supply per capita  \
# Country
# China                1.271910e+11                      93.0
# India                3.319500e+10                      26.0
# United States        9.083800e+10                     286.0
# Brazil               1.214900e+10                      59.0
# Russian Federation   3.070900e+10                     214.0
# Japan                1.898400e+10                     149.0
# Germany              1.326100e+10                     165.0
# Iran                 9.172000e+09                     119.0
# United Kingdom       7.920000e+09                     124.0
# France               1.059700e+10                     166.0
# Italy                6.530000e+09                     109.0
# South Korea          1.100700e+10                     221.0
# Spain                4.923000e+09                     106.0
# Canada               1.043100e+10                     296.0
# ...

# %%
ContinentDict = {'China':'Asia', 'United States':'North America', 'Japan':'Asia', 'United Kingdom':'Europe', 'Russian Federation':'Europe', 'Canada':'North America',
 'Germany':'Europe',
 'India':'Asia',
 'France':'Europe',
 'South Korea':'Asia',
 'Italy':'Europe',
 'Spain':'Europe',
 'Iran':'Asia',
 'Australia':'Australia',
 'Brazil':'South America'}

# %%
df7=pd.DataFrame(ContinentDict.items())#dict to dataframe
df7.columns=['Country','Continent']#dataframe columns
df7.groupby('Continent').groups#groupby and get groups
# Out:
# {'Asia': [0, 2, 7, 9, 12], 'Australia': [13], 'Europe': [3, 4, 6, 8, 10, 11], 'North America': [1, 5], 'South America': [14]}

# %%
df6.rename(index=ContinentDict,inplace=True)
df6.reset_index(inplace = True)
functions = ['size', 'sum', 'mean', 'std']
result = df6[['Country','Polpulation']].groupby('Country').agg(functions)

# %%
result
# Out:
#               Polpulation
#                      size           sum          mean           std
# Country
# Asia                    5  2.898666e+09  5.797333e+08  6.790979e+08
# Australia               1  2.331602e+07  2.331602e+07           NaN
# Europe                  6  4.579297e+08  7.632161e+07  3.464767e+07
# North America           2  3.528552e+08  1.764276e+08  1.996696e+08
# South America           1  2.059153e+08  2.059153e+08           NaN
